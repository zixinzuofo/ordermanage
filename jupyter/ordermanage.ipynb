# %%
import requests
import json
import pymysql

# %% [markdown]
# # 注册

# %%
# url = 'http://localhost:9999/ordermanage/signup'
# url = 'https://ordermanage.dollto-china.com/ordermanage/signup'
url = 'http://ordermanage.df-ordermanage.com/ordermanage/signup'
data = {
    'userName': '冬明',
    'password': '123',
    'email': '18967140897@163.com'
}
res = requests.post(url=url, json=data)
res.json()
# Out:
# {'ret': 0, 'msg': 'success'}

# %% [markdown]
# # 登录

# %%
# url = 'http://localhost:9999/ordermanage/login'
# url = 'https://ordermanage.dollto-china.com/ordermanage/login'
url = 'http://ordermanage.df-ordermanage.com/ordermanage/login'
data = {
    'userName': '冬明',
    'password': '123'
}
res = requests.post(url=url, json=data)
try:
    res.json()
    token = res.json()['token']
except:
    print(res.text)

# %% [markdown]
# # 查询用户权限

# %%
url = 'http://localhost:9999/ordermanage/user/query/permission'
# url = 'https://ordermanage.dollto-china.com/ordermanage/user/query/permission'
headers = {
    'authorization': token
}
data = {
    'userName': '冬明',
    'queriedUserName': '冬明'
}
res = requests.post(url=url, headers=headers, json=data)
try:
    res.json()
    token = res.json()['token']
except:
    print(res.text)
# Out:
# {"ret":0,"msg":"success","data":[{"role":"normalUser","orderPlacedDate":0,"yearNumber":0,"monthNumber":0,"orderId":0,"comment":0,"orderSource":0,"paymentMethod":0,"brandName":"","height":0,"bodyShape":0,"head":0,"paymentUSD":0,"paymentCNY":0,"factoryCost":0,"EVO":0,"extraHead":0,"luckyBox":0,"flightCase":0,"DHLEUB":0,"accessoriesPrice":0,"otherAccessories":0,"shippingCost":0,"totalProfit":0,"commission":0,"commissionPercentage":0,"designer":0,"companyProfit":0,"confirmTime":0,"shipTime":0,"shippingAgent":0,"domesticTrackingNumber":0,"trackingNumber":0,"salesRep":0,"checkStatus":0,"orderFlag":3}]}

# %% [markdown]
# # 发送验证码

# %%
# url = 'http://localhost:9999/ordermanage/user/generate/verifyCode'
url = 'https://ordermanage.dollto-china.com/ordermanage/user/generate/verifyCode'
headers = {
    'authorization': token
}
data = {
    'userName': 'zhangdongming'
}
res = requests.post(url=url, headers=headers, json=data)
res.json()
# Out:
# {'ret': 0, 'msg': 'success'}

# %% [markdown]
# # 重置密码

# %%
url = 'http://localhost:9999/ordermanage/user/reset/password'
# url = 'https://ordermanage.dollto-china.com/ordermanage/user/reset/password'
headers = {
    'authorization': token
}
data = {
    'userName': 'zhangdongming',
    'verifyCode': '53g4kh',
    'newPassword': '1234'
}
res = requests.post(url=url, headers=headers, json=data)
res.json()
# Out:
# {'ret': -1014, 'msg': 'verifyCode not found'}

# %% [markdown]
# # 修改密码

# %%
url = 'http://localhost:9999/ordermanage/user/update/password'
# url = 'https://ordermanage.dollto-china.com/ordermanage/user/update/password'
headers = {
    'authorization': token
}
data = {
    'userName': '冬明',
    'oldPassword': '123',
    'newPassword': '1234'
}
res = requests.post(url=url, headers=headers, json=data)
res.json()
# Out:
# {'ret': 0, 'msg': 'success'}

# %% [markdown]
# # 新增AuthenticCode

# %%
url = 'http://ordermanage.df-ordermanage.com/ordermanage/authenticCode/add'
headers = {
    'authorization': token
}
data = {
    'userName': '冬明',
    'authenticCode': 'efg',
    'productInfo': 'test'
}
res = requests.post(url=url, headers=headers, json=data)
res.json()
# Out:
# {'ret': 0, 'msg': 'success'}

# %% [markdown]
# # 删除AuthenticCode

# %%
url = 'http://ordermanage.df-ordermanage.com/ordermanage/authenticCode/delete'
headers = {
    'authorization': token
}
data = {
    'userName': '冬明',
    'authenticCode': 'xyz'
}
res = requests.post(url=url, headers=headers, json=data)
res.json()
# Out:
# {'ret': 0, 'msg': 'success'}

# %% [markdown]
# # 修改AuthenticCode

# %%
url = 'http://ordermanage.df-ordermanage.com/ordermanage/authenticCode/update'
headers = {
    'authorization': token
}
data = {
    'userName': '冬明',
    'authenticCode': 'abc',
    'productInfo': 'test1'
}
res = requests.post(url=url, headers=headers, json=data)
res.json()
# Out:
# {'ret': 0, 'msg': 'success'}

# %% [markdown]
# # 查询AuthenticCode

# %%
url = 'http://ordermanage.df-ordermanage.com/ordermanage/authenticCode/query'
headers = {
    'authorization': token
}
data = {
    'userName': '冬明',
    'authenticCode': 'ABCD'
}
res = requests.post(url=url, headers=headers, json=data)
res.json()
# Out:
# {'ret': 0,
#  'msg': 'success',
#  'data': [{'id': 14,
#    'authenticCode': 'ABCD',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 21:34:50',
#    'creator': None,
#    'updator': 'Admin'}]}

# %% [markdown]
# # 查询N个AuthenticCode

# %%
url = 'http://ordermanage.df-ordermanage.com/ordermanage/authenticCode/query/number'
headers = {
    'authorization': token
}
data = {
    'userName': '冬明',
    'number': 1000000
}
res = requests.post(url=url, headers=headers, json=data)
res.json()
# Out:
# {'ret': 0,
#  'msg': 'success',
#  'count': 98,
#  'data': [{'id': 224,
#    'authenticCode': 'fVZKSgHm12',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-31 21:54:23',
#    'updateTime': '2024-08-31 21:56:50',
#    'creator': 'Admin',
#    'updator': 'Admin'},
#   {'id': 221,
#    'authenticCode': 'xEJSyq52I5',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-31 21:54:23',
#    'updateTime': '2024-08-31 21:54:23',
#    'creator': 'Admin',
#    'updator': 'Admin'},
#   {'id': 225,
#    'authenticCode': 'qmaSerenGT',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-31 21:54:23',
#    'updateTime': '2024-08-31 21:54:23',
#    'creator': 'Admin',
#    'updator': 'Admin'},
#   {'id': 229,
#    'authenticCode': 'GzScYyHN12',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-31 21:54:23',
#    'updateTime': '2024-08-31 21:54:23',
#    'creator': 'Admin',
#    'updator': 'Admin'},
#   {'id': 233,
#    'authenticCode': '8fhTIXVm8J',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-31 21:54:23',
#    'updateTime': '2024-08-31 21:54:23',
#    'creator': 'Admin',
#    'updator': 'Admin'},
#   {'id': 237,
#    'authenticCode': 'E1oNwtfZSf',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-31 21:54:23',
#    'updateTime': '2024-08-31 21:54:23',
#    'creator': 'Admin',
#    'updator': 'Admin'},
#   {'id': 241,
#    'authenticCode': 'SyUPsz6mgI',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-31 21:54:23',
#    'updateTime': '2024-08-31 21:54:23',
#    'creator': 'Admin',
#    'updator': 'Admin'},
#   {'id': 245,
#    'authenticCode': 'KbukJtqJKS',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-31 21:54:23',
#    'updateTime': '2024-08-31 21:54:23',
#    'creator': 'Admin',
#    'updator': 'Admin'},
#   {'id': 249,
#    'authenticCode': 'syxRnmKOQO',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-31 21:54:23',
#    'updateTime': '2024-08-31 21:54:23',
#    'creator': 'Admin',
#    'updator': 'Admin'},
#   {'id': 253,
#    'authenticCode': 'ix3ss8O0Cs',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-31 21:54:23',
#    'updateTime': '2024-08-31 21:54:23',
#    'creator': 'Admin',
#    'updator': 'Admin'},
#   {'id': 257,
#    'authenticCode': 'th89H4AhVi',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-31 21:54:23',
#    'updateTime': '2024-08-31 21:54:23',
#    'creator': 'Admin',
#    'updator': 'Admin'},
#   {'id': 94,
#    'authenticCode': 'spWA8D5cDjPl7b4',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 20:41:20',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 98,
#    'authenticCode': 'BMMfJkf1rD',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 20:41:21',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 102,
#    'authenticCode': '3NCPmGJX0Y',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 20:41:22',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 106,
#    'authenticCode': '4QohRu6f8Q',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 20:41:23',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 110,
#    'authenticCode': 'rJMMVxR6wx',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 20:41:24',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 114,
#    'authenticCode': 'qWYZRJdcib',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 20:41:25',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 118,
#    'authenticCode': 'Pkd6FqBu8N',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 20:41:26',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 122,
#    'authenticCode': 'j9PHwdvcLq',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 20:41:28',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 126,
#    'authenticCode': 'jlrNGASSL6',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 20:41:29',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 130,
#    'authenticCode': 'bLjs1s6baW',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 20:41:30',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 134,
#    'authenticCode': '1lRm251Hus',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 20:41:31',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 138,
#    'authenticCode': 'SpJwcu7KJU',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 20:41:33',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 142,
#    'authenticCode': 'ElLF5zyHS0',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 20:41:35',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 146,
#    'authenticCode': 'K17VHE3X1f',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 20:41:36',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 150,
#    'authenticCode': 'SjgVOO2BQu',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 20:41:37',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 154,
#    'authenticCode': 'fV4yygaLhG',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 20:41:38',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 158,
#    'authenticCode': 'ABCDEFGHIJK1234',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 20:41:39',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 162,
#    'authenticCode': 'Bw4apFbpYk',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 20:41:40',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 166,
#    'authenticCode': 'HpAEIoQqkx',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 20:41:41',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 170,
#    'authenticCode': 'JKHhTa21YK',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 20:41:42',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 174,
#    'authenticCode': '50BDtUAcHd',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 20:41:43',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 178,
#    'authenticCode': 'COXyygXwnD',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 20:41:45',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 194,
#    'authenticCode': 'qqq',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 21:47:28',
#    'updateTime': '2024-08-30 21:47:28',
#    'creator': '冬明',
#    'updator': '冬明'},
#   {'id': 202,
#    'authenticCode': 'XRfYa0m3cnmov0CM',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-31 21:21:20',
#    'updateTime': '2024-08-31 21:21:20',
#    'creator': 'Admin',
#    'updator': 'Admin'},
#   {'id': 206,
#    'authenticCode': 'f817s1aobdlEmduG',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-31 21:21:20',
#    'updateTime': '2024-08-31 21:21:20',
#    'creator': 'Admin',
#    'updator': 'Admin'},
#   {'id': 210,
#    'authenticCode': 'lHZ3QhEdTK',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-31 21:54:23',
#    'updateTime': '2024-08-31 21:54:23',
#    'creator': 'Admin',
#    'updator': 'Admin'},
#   {'id': 214,
#    'authenticCode': '4IO4Rc8NtQ',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-31 21:54:23',
#    'updateTime': '2024-08-31 21:54:23',
#    'creator': 'Admin',
#    'updator': 'Admin'},
#   {'id': 218,
#    'authenticCode': 'HqwNN4RJb9',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-31 21:54:23',
#    'updateTime': '2024-08-31 21:54:23',
#    'creator': 'Admin',
#    'updator': 'Admin'},
#   {'id': 222,
#    'authenticCode': '8WBRx4z07x',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-31 21:54:23',
#    'updateTime': '2024-08-31 21:54:23',
#    'creator': 'Admin',
#    'updator': 'Admin'},
#   {'id': 226,
#    'authenticCode': 'XwnLnRByFn',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-31 21:54:23',
#    'updateTime': '2024-08-31 21:54:23',
#    'creator': 'Admin',
#    'updator': 'Admin'},
#   {'id': 230,
#    'authenticCode': '3dfPf44dEt',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-31 21:54:23',
#    'updateTime': '2024-08-31 21:54:23',
#    'creator': 'Admin',
#    'updator': 'Admin'},
#   {'id': 234,
#    'authenticCode': '6lRXTvsqrv',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-31 21:54:23',
#    'updateTime': '2024-08-31 21:54:23',
#    'creator': 'Admin',
#    'updator': 'Admin'},
#   {'id': 238,
#    'authenticCode': 'wx0vuYl034',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-31 21:54:23',
#    'updateTime': '2024-08-31 21:54:23',
#    'creator': 'Admin',
#    'updator': 'Admin'},
#   {'id': 242,
#    'authenticCode': 'USunhKq8oO',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-31 21:54:23',
#    'updateTime': '2024-08-31 21:54:23',
#    'creator': 'Admin',
#    'updator': 'Admin'},
#   {'id': 246,
#    'authenticCode': 'uIZfU41O1U',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-31 21:54:23',
#    'updateTime': '2024-08-31 21:54:23',
#    'creator': 'Admin',
#    'updator': 'Admin'},
#   {'id': 250,
#    'authenticCode': 't8ajdGfc1L',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-31 21:54:23',
#    'updateTime': '2024-08-31 21:54:23',
#    'creator': 'Admin',
#    'updator': 'Admin'},
#   {'id': 254,
#    'authenticCode': '7DvcwnqrKn',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-31 21:54:23',
#    'updateTime': '2024-08-31 21:54:23',
#    'creator': 'Admin',
#    'updator': 'Admin'},
#   {'id': 258,
#    'authenticCode': 'VBeaTNcXRp',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-31 21:54:23',
#    'updateTime': '2024-08-31 21:54:23',
#    'creator': 'Admin',
#    'updator': 'Admin'},
#   {'id': 47,
#    'authenticCode': 'P4AJrSKE86PO6Bm',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 20:41:05',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 51,
#    'authenticCode': 'trDjAiDCQVTw2Kx',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 20:41:06',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 55,
#    'authenticCode': 'WSSBIT2iX9',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 20:41:07',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 59,
#    'authenticCode': 'KtuBjL9X0w',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 20:41:09',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 63,
#    'authenticCode': 'OZgHlVUwSb',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 20:41:09',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 67,
#    'authenticCode': 'ULHuaiNr1t',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 20:41:11',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 71,
#    'authenticCode': 'vVBwnfBYl1',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 20:41:12',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 75,
#    'authenticCode': 'YdlNYb6LSn8NFl8',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 20:41:14',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 79,
#    'authenticCode': '9mH60x9XVPpHJuO',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 20:41:15',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 83,
#    'authenticCode': 'Abr75Uwg2oHN39E',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 20:41:16',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 87,
#    'authenticCode': 'bstP6FjBYzeoPUL',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 20:41:17',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 91,
#    'authenticCode': 'nibui3sH9dgp5tU',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 20:41:19',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 95,
#    'authenticCode': 'JemQSeVRfy6rorG',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 20:41:20',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 99,
#    'authenticCode': 'ioBTOcvJnn',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 20:41:21',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 103,
#    'authenticCode': '32ZjBbOAPh',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 20:41:23',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 107,
#    'authenticCode': 'iOqOUvpyQB',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 20:41:23',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 111,
#    'authenticCode': 'VvMvwOHlk7',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 20:41:25',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 115,
#    'authenticCode': 'TMR3hSfjpM',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 20:41:26',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 119,
#    'authenticCode': 'DzEHjZYk4X',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 20:41:27',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 123,
#    'authenticCode': 'yAfS0zm0ks',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 20:41:28',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 127,
#    'authenticCode': 'jfluAkvH2x',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 20:41:29',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 131,
#    'authenticCode': '88Fd12SmP8',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 20:41:30',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 135,
#    'authenticCode': 'YiDb6dSb6h',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 20:41:32',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 139,
#    'authenticCode': '6YgKfIdJMa',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 20:41:34',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 143,
#    'authenticCode': 'dE4T8LjFms',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 20:41:35',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 147,
#    'authenticCode': 'B2bRVQw8En',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 20:41:36',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 151,
#    'authenticCode': 'QlpCa3uMhU',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 20:41:37',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 155,
#    'authenticCode': 'yt60EI0HFk',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 20:41:39',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 159,
#    'authenticCode': 'ABCDEFGHIJK12345',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 20:41:39',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 163,
#    'authenticCode': 'UiEXCL5bs1',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 20:41:40',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 167,
#    'authenticCode': 'YzdhshNHwv',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 20:41:41',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 171,
#    'authenticCode': 'gIAuyKqeSF',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 20:41:43',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 175,
#    'authenticCode': '6O5IMG5mLd',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 20:41:44',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 179,
#    'authenticCode': 'RtI8vgtHm3',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 20:41:45',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 199,
#    'authenticCode': 'nL6T67EWCExYHep4',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-31 21:21:20',
#    'updateTime': '2024-08-31 21:21:20',
#    'creator': 'Admin',
#    'updator': 'Admin'},
#   {'id': 203,
#    'authenticCode': 'skyobMDpxud82OZ5',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-31 21:21:20',
#    'updateTime': '2024-08-31 21:21:20',
#    'creator': 'Admin',
#    'updator': 'Admin'},
#   {'id': 207,
#    'authenticCode': 'TJOvRIv8yCrZuquX',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-31 21:21:20',
#    'updateTime': '2024-08-31 21:21:20',
#    'creator': 'Admin',
#    'updator': 'Admin'},
#   {'id': 211,
#    'authenticCode': 'S4iRfqPr8p',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-31 21:54:23',
#    'updateTime': '2024-08-31 21:54:23',
#    'creator': 'Admin',
#    'updator': 'Admin'},
#   {'id': 215,
#    'authenticCode': 'fsuG8ArPIl',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-31 21:54:23',
#    'updateTime': '2024-08-31 21:54:23',
#    'creator': 'Admin',
#    'updator': 'Admin'},
#   {'id': 219,
#    'authenticCode': 'JZeaMsbxSr',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-31 21:54:23',
#    'updateTime': '2024-08-31 21:54:23',
#    'creator': 'Admin',
#    'updator': 'Admin'},
#   {'id': 223,
#    'authenticCode': 'jD76ldcar6',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-31 21:54:23',
#    'updateTime': '2024-08-31 21:54:23',
#    'creator': 'Admin',
#    'updator': 'Admin'},
#   {'id': 227,
#    'authenticCode': 'Gv8jWKz7Fp',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-31 21:54:23',
#    'updateTime': '2024-08-31 21:54:23',
#    'creator': 'Admin',
#    'updator': 'Admin'},
#   {'id': 231,
#    'authenticCode': 's2xaJaplJv',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-31 21:54:23',
#    'updateTime': '2024-08-31 21:54:23',
#    'creator': 'Admin',
#    'updator': 'Admin'},
#   {'id': 235,
#    'authenticCode': 'wcGRnW1GM9',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-31 21:54:23',
#    'updateTime': '2024-08-31 21:54:23',
#    'creator': 'Admin',
#    'updator': 'Admin'},
#   {'id': 239,
#    'authenticCode': 'FzvwAMqrT7',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-31 21:54:23',
#    'updateTime': '2024-08-31 21:54:23',
#    'creator': 'Admin',
#    'updator': 'Admin'},
#   {'id': 243,
#    'authenticCode': '9qgECoYmn9',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-31 21:54:23',
#    'updateTime': '2024-08-31 21:54:23',
#    'creator': 'Admin',
#    'updator': 'Admin'},
#   {'id': 247,
#    'authenticCode': 'QSP7aS3XTB',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-31 21:54:23',
#    'updateTime': '2024-08-31 21:54:23',
#    'creator': 'Admin',
#    'updator': 'Admin'},
#   {'id': 251,
#    'authenticCode': 'gmRMRf16cx',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-31 21:54:23',
#    'updateTime': '2024-08-31 21:54:23',
#    'creator': 'Admin',
#    'updator': 'Admin'},
#   {'id': 255,
#    'authenticCode': 'tqHKCCukjV',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-31 21:54:23',
#    'updateTime': '2024-08-31 21:54:23',
#    'creator': 'Admin',
#    'updator': 'Admin'}]}

# %% [markdown]
# # 查询所有AuthenticCode

# %%
url = 'http://ordermanage.df-ordermanage.com/ordermanage/authenticCode/query/all'
headers = {
    'authorization': token
}
data = {
    'userName': '冬明'
}
res = requests.post(url=url, headers=headers, json=data)
res.json()
# Out:
# {'ret': 0,
#  'msg': 'success',
#  'count': 230,
#  'data': [{'id': 2,
#    'authenticCode': 'ABCDEFGHIJK123',
#    'productInfo': 'test',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 21:34:48',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 5,
#    'authenticCode': 'POIA0RQ5JLN49Q',
#    'productInfo': 'test',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 21:34:48',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 6,
#    'authenticCode': 'BWGY7U7HYXQZ0N',
#    'productInfo': 'test',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 21:34:48',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 7,
#    'authenticCode': 'EDQP8ZSW4S9ZIR',
#    'productInfo': 'test',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 21:34:49',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 8,
#    'authenticCode': 'TE825LJMWFS5MR',
#    'productInfo': 'test',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 21:34:49',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 9,
#    'authenticCode': 'P7ISIILEBER5CK',
#    'productInfo': 'test',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 21:34:50',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 10,
#    'authenticCode': '5T04RVXNUYK1C4',
#    'productInfo': 'test',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 21:34:50',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 14,
#    'authenticCode': 'ABCD',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 21:34:50',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 19,
#    'authenticCode': 'ABCDE',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 21:34:51',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 20,
#    'authenticCode': 'ABCDEF',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 21:34:51',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 24,
#    'authenticCode': 'g7iyHmTN3N',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 21:35:28',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 25,
#    'authenticCode': 'lqaVzckI7H',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 21:35:28',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 26,
#    'authenticCode': 'nmT0dClcya',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 21:35:29',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 27,
#    'authenticCode': '2VwI0zHIxE',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 21:35:29',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 28,
#    'authenticCode': 'XSlnaAr7wR',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 21:35:29',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 29,
#    'authenticCode': 'rOcr22Ybig',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 21:35:29',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 30,
#    'authenticCode': 'fLO5Fn5lQy',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 21:35:30',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 31,
#    'authenticCode': 'hioWpEYx3q',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 21:35:30',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 32,
#    'authenticCode': 'U6ikAeD50n',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 21:35:31',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 33,
#    'authenticCode': 'tZE5AmJ3Xz',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 21:35:31',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 34,
#    'authenticCode': 'qGaWf1b2bKtX',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 21:35:31',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 35,
#    'authenticCode': 'jd8ynehb1sQR',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 21:35:32',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 36,
#    'authenticCode': 'uZc5Wr31IIwL',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 21:35:32',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 37,
#    'authenticCode': '40rw36JkDoQ3',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 21:35:32',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 38,
#    'authenticCode': 'S50DBYwNjhAi',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 21:35:33',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 39,
#    'authenticCode': 'G1pwTVrcikX8',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 21:35:33',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 40,
#    'authenticCode': '4FMWX98iFfx3',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 21:35:33',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 41,
#    'authenticCode': 'amPHQC8MyO3H',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 21:35:33',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 42,
#    'authenticCode': 'ea3scJVLIKAS',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 21:35:34',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 43,
#    'authenticCode': 'XfMqo8mOJaZO',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 21:35:34',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 44,
#    'authenticCode': 'zGT4zi69vDgqjI8',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 21:54:50',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 45,
#    'authenticCode': 'CZrQSrdqbtBv7X3',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 21:58:21',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 46,
#    'authenticCode': 'L6HmXfKivnHPlqr',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-31 20:57:38',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 47,
#    'authenticCode': 'P4AJrSKE86PO6Bm',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 20:41:05',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 48,
#    'authenticCode': 'G1fufXtBDrPhqpV',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 21:54:50',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 49,
#    'authenticCode': 'PS51ST8f5emVFHl',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 21:58:21',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 50,
#    'authenticCode': '2aGFS41XMaYKVLK',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-31 20:57:38',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 51,
#    'authenticCode': 'trDjAiDCQVTw2Kx',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 20:41:06',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 52,
#    'authenticCode': 'CQvSXaE5hTIhYFd',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 21:54:51',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 53,
#    'authenticCode': 'HRgGAmDjvnLHG1G',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 21:58:22',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 54,
#    'authenticCode': 'M3xmm4YnBR',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-31 20:57:38',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 55,
#    'authenticCode': 'WSSBIT2iX9',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 20:41:07',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 56,
#    'authenticCode': 'N28e8i3ubv',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 21:54:51',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 57,
#    'authenticCode': 'Xw78ZKzeVU',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 21:58:22',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 58,
#    'authenticCode': 'vu7pFsppkn',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-31 20:57:38',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 59,
#    'authenticCode': 'KtuBjL9X0w',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 20:41:09',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 60,
#    'authenticCode': 'FE991dALu4',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 21:54:51',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 61,
#    'authenticCode': 'I4jyd1H47X',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 21:58:22',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 62,
#    'authenticCode': '6U4TbL1fWJ',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-31 20:57:38',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 63,
#    'authenticCode': 'OZgHlVUwSb',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 20:41:09',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 64,
#    'authenticCode': '3P5EpAGOgj',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 21:54:52',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 65,
#    'authenticCode': '8g4AbUpaoF',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 22:14:35',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 66,
#    'authenticCode': 'NwaAnbfGzb',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-31 20:57:38',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 67,
#    'authenticCode': 'ULHuaiNr1t',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 20:41:11',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 68,
#    'authenticCode': '1BaSMry8nF',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 21:54:52',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 69,
#    'authenticCode': 'E8snrn2wDr',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-31 20:54:13',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 70,
#    'authenticCode': 'pG68jLBcYN',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-31 20:57:38',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 71,
#    'authenticCode': 'vVBwnfBYl1',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 20:41:12',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 72,
#    'authenticCode': 'E7CnZ3FgM3',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 21:54:52',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 73,
#    'authenticCode': 'KTj3Sr04j5',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-31 20:54:13',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 74,
#    'authenticCode': 'XNleePB7wC09V20',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-31 20:57:38',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 75,
#    'authenticCode': 'YdlNYb6LSn8NFl8',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 20:41:14',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 76,
#    'authenticCode': '1alREo0SKX4pEgy',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 21:54:53',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 77,
#    'authenticCode': 'oQqcH3aTXfqxd3R',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-31 20:54:13',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 78,
#    'authenticCode': 'xy15lYbDDvBMAIr',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-31 20:57:38',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 79,
#    'authenticCode': '9mH60x9XVPpHJuO',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 20:41:15',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 80,
#    'authenticCode': 'FM0v5DwxhbdLmNP',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 21:54:53',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 81,
#    'authenticCode': 'cXEp0Fo1ayjXkAw',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-31 20:54:13',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 82,
#    'authenticCode': '7KZ21BLU85VaVj8',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-31 20:57:38',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 83,
#    'authenticCode': 'Abr75Uwg2oHN39E',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 20:41:16',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 84,
#    'authenticCode': 'nmu8f0sKieOlAtE',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 21:54:53',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 85,
#    'authenticCode': 'gG7khLAL4dStrbw',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-31 20:54:13',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 86,
#    'authenticCode': 'wpu3RCODBSPJqDl',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-31 20:57:38',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 87,
#    'authenticCode': 'bstP6FjBYzeoPUL',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 20:41:17',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 88,
#    'authenticCode': 'OevRMgTUDzIGMUG',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 21:54:54',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 89,
#    'authenticCode': 'xh324sAQ8Dct386',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-31 20:54:13',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 90,
#    'authenticCode': 'fmknYOwMGivkJnR',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-31 20:57:38',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 91,
#    'authenticCode': 'nibui3sH9dgp5tU',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 20:41:19',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 92,
#    'authenticCode': 'vhxPAM7IiVB9NqS',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 21:54:54',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 93,
#    'authenticCode': 's2uS3bqzAD9zYT6',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-31 20:54:13',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 94,
#    'authenticCode': 'spWA8D5cDjPl7b4',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 20:41:20',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 95,
#    'authenticCode': 'JemQSeVRfy6rorG',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 20:41:20',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 96,
#    'authenticCode': 'mlEf1nC21F',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 21:54:54',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 97,
#    'authenticCode': '5gyXKsEh2i',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-31 20:54:13',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 98,
#    'authenticCode': 'BMMfJkf1rD',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 20:41:21',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 99,
#    'authenticCode': 'ioBTOcvJnn',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 20:41:21',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 100,
#    'authenticCode': 'dHOGB7M53t',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 21:54:54',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 101,
#    'authenticCode': 'OhdBbTxCiC',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-31 20:54:13',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 102,
#    'authenticCode': '3NCPmGJX0Y',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 20:41:22',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 103,
#    'authenticCode': '32ZjBbOAPh',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 20:41:23',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 104,
#    'authenticCode': 'ZmotV8x2pq',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 21:54:55',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 105,
#    'authenticCode': 'LuZo4Wivot',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-31 20:54:13',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 106,
#    'authenticCode': '4QohRu6f8Q',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 20:41:23',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 107,
#    'authenticCode': 'iOqOUvpyQB',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 20:41:23',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 108,
#    'authenticCode': 'wRkDbVU23M',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 21:54:55',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 109,
#    'authenticCode': 'VCP4K2p5LB',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-31 20:54:13',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 110,
#    'authenticCode': 'rJMMVxR6wx',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 20:41:24',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 111,
#    'authenticCode': 'VvMvwOHlk7',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 20:41:25',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 112,
#    'authenticCode': 'xMaAhsxWaX',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 21:54:55',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 113,
#    'authenticCode': 'fFn3olyniA',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-31 20:54:13',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 114,
#    'authenticCode': 'qWYZRJdcib',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 20:41:25',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 115,
#    'authenticCode': 'TMR3hSfjpM',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 20:41:26',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 116,
#    'authenticCode': '5PBcPnAtYo',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 21:54:56',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 117,
#    'authenticCode': 'lxRmZt9noo',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-31 20:54:13',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 118,
#    'authenticCode': 'Pkd6FqBu8N',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 20:41:26',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 119,
#    'authenticCode': 'DzEHjZYk4X',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 20:41:27',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 120,
#    'authenticCode': 'tu4PqHhK61',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 21:54:56',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 121,
#    'authenticCode': 'dhFTw0FkvH',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-31 20:54:13',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 122,
#    'authenticCode': 'j9PHwdvcLq',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 20:41:28',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 123,
#    'authenticCode': 'yAfS0zm0ks',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 20:41:28',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 124,
#    'authenticCode': 'sKf6xJYkWW',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 21:57:02',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 125,
#    'authenticCode': '0L3BSfCvuR',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-31 20:54:13',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 126,
#    'authenticCode': 'jlrNGASSL6',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 20:41:29',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 127,
#    'authenticCode': 'jfluAkvH2x',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 20:41:29',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 128,
#    'authenticCode': '6dcAEZFadK',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 21:57:02',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 129,
#    'authenticCode': 'eD7iik5DRN',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-31 20:54:13',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 130,
#    'authenticCode': 'bLjs1s6baW',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 20:41:30',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 131,
#    'authenticCode': '88Fd12SmP8',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 20:41:30',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 132,
#    'authenticCode': 'WPuqFY93r6',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 21:57:03',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 133,
#    'authenticCode': 'aaOw6nkh2W',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-31 20:54:13',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 134,
#    'authenticCode': '1lRm251Hus',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 20:41:31',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 135,
#    'authenticCode': 'YiDb6dSb6h',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 20:41:32',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 136,
#    'authenticCode': 'egKPYC25vn',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 21:57:03',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 137,
#    'authenticCode': 'keVTvyJBSn',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-31 20:54:13',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 138,
#    'authenticCode': 'SpJwcu7KJU',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 20:41:33',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 139,
#    'authenticCode': '6YgKfIdJMa',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 20:41:34',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 140,
#    'authenticCode': 'F3NVRXu4fi',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 21:57:03',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 141,
#    'authenticCode': 'WeYiDMOm8s',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-31 20:54:13',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 142,
#    'authenticCode': 'ElLF5zyHS0',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 20:41:35',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 143,
#    'authenticCode': 'dE4T8LjFms',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 20:41:35',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 144,
#    'authenticCode': 'WO06PtuO4L',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 21:57:04',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 145,
#    'authenticCode': '54VrmHv5Tr',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-31 20:54:13',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 146,
#    'authenticCode': 'K17VHE3X1f',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 20:41:36',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 147,
#    'authenticCode': 'B2bRVQw8En',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 20:41:36',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 148,
#    'authenticCode': 'i1Gpm6qei7',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 21:57:04',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 149,
#    'authenticCode': 'vI6q2sj5yM',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-31 20:57:38',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 150,
#    'authenticCode': 'SjgVOO2BQu',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 20:41:37',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 151,
#    'authenticCode': 'QlpCa3uMhU',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 20:41:37',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 152,
#    'authenticCode': 'QQqvrx8c9B',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 21:57:05',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 153,
#    'authenticCode': 'mLECsRy5hh',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-31 20:57:38',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 154,
#    'authenticCode': 'fV4yygaLhG',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 20:41:38',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 155,
#    'authenticCode': 'yt60EI0HFk',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 20:41:39',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 158,
#    'authenticCode': 'ABCDEFGHIJK1234',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 20:41:39',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 159,
#    'authenticCode': 'ABCDEFGHIJK12345',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 20:41:39',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 160,
#    'authenticCode': 'ABCDEFGHIJK123456',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 21:57:05',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 161,
#    'authenticCode': 'Vkv8RmWpeD',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-31 20:57:38',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 162,
#    'authenticCode': 'Bw4apFbpYk',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 20:41:40',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 163,
#    'authenticCode': 'UiEXCL5bs1',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 20:41:40',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 164,
#    'authenticCode': 'h9bVnpaob3',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 21:57:06',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 165,
#    'authenticCode': 'ESLXFERmmi',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-31 20:57:38',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 166,
#    'authenticCode': 'HpAEIoQqkx',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 20:41:41',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 167,
#    'authenticCode': 'YzdhshNHwv',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 20:41:41',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 168,
#    'authenticCode': 'QZ5lXDDYTy',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 21:58:19',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 169,
#    'authenticCode': 'ULBRNYInhh',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-31 20:57:38',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 170,
#    'authenticCode': 'JKHhTa21YK',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 20:41:42',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 171,
#    'authenticCode': 'gIAuyKqeSF',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 20:41:43',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 172,
#    'authenticCode': 'Pj7vxFurUG',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 21:58:20',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 173,
#    'authenticCode': 'ZQeOSf5SpS',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-31 20:57:38',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 174,
#    'authenticCode': '50BDtUAcHd',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 20:41:43',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 175,
#    'authenticCode': '6O5IMG5mLd',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 20:41:44',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 176,
#    'authenticCode': 'veSZUOXTJc',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 21:58:20',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 177,
#    'authenticCode': 'OI1L1r07dC',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-31 20:57:38',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 178,
#    'authenticCode': 'COXyygXwnD',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 20:41:45',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 179,
#    'authenticCode': 'RtI8vgtHm3',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 20:41:45',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 180,
#    'authenticCode': 'VBg3eA9vxL',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 19:36:51',
#    'updateTime': '2024-08-30 21:58:20',
#    'creator': None,
#    'updator': 'Admin'},
#   {'id': 183,
#    'authenticCode': 'mnl',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 21:34:20',
#    'updateTime': '2024-08-30 22:09:19',
#    'creator': '冬明',
#    'updator': '冬明'},
#   {'id': 184,
#    'authenticCode': 'hij',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 21:34:20',
#    'updateTime': '2024-08-30 21:58:21',
#    'creator': '冬明',
#    'updator': 'Admin'},
#   {'id': 193,
#    'authenticCode': 'ppp',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 21:47:28',
#    'updateTime': '2024-08-31 20:57:38',
#    'creator': '冬明',
#    'updator': 'Admin'},
#   {'id': 194,
#    'authenticCode': 'qqq',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-30 21:47:28',
#    'updateTime': '2024-08-30 21:47:28',
#    'creator': '冬明',
#    'updator': '冬明'},
#   {'id': 195,
#    'authenticCode': 'ABC',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-30 21:47:28',
#    'updateTime': '2024-08-30 22:09:41',
#    'creator': '冬明',
#    'updator': '冬明'},
#   {'id': 199,
#    'authenticCode': 'nL6T67EWCExYHep4',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-31 21:21:20',
#    'updateTime': '2024-08-31 21:21:20',
#    'creator': 'Admin',
#    'updator': 'Admin'},
#   {'id': 200,
#    'authenticCode': 'GbVkjpXaTHwH0nDH',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-31 21:21:20',
#    'updateTime': '2024-08-31 21:56:36',
#    'creator': 'Admin',
#    'updator': 'Admin'},
#   {'id': 201,
#    'authenticCode': 'E9e0zwg3sjSTbwLo',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-31 21:21:20',
#    'updateTime': '2024-08-31 21:56:36',
#    'creator': 'Admin',
#    'updator': 'Admin'},
#   {'id': 202,
#    'authenticCode': 'XRfYa0m3cnmov0CM',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-31 21:21:20',
#    'updateTime': '2024-08-31 21:21:20',
#    'creator': 'Admin',
#    'updator': 'Admin'},
#   {'id': 203,
#    'authenticCode': 'skyobMDpxud82OZ5',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-31 21:21:20',
#    'updateTime': '2024-08-31 21:21:20',
#    'creator': 'Admin',
#    'updator': 'Admin'},
#   {'id': 204,
#    'authenticCode': '6nH6QLySKVD4hYN0',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-31 21:21:20',
#    'updateTime': '2024-08-31 21:56:36',
#    'creator': 'Admin',
#    'updator': 'Admin'},
#   {'id': 205,
#    'authenticCode': 'H3aTC4foycM1mAq1',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-31 21:21:20',
#    'updateTime': '2024-08-31 21:56:36',
#    'creator': 'Admin',
#    'updator': 'Admin'},
#   {'id': 206,
#    'authenticCode': 'f817s1aobdlEmduG',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-31 21:21:20',
#    'updateTime': '2024-08-31 21:21:20',
#    'creator': 'Admin',
#    'updator': 'Admin'},
#   {'id': 207,
#    'authenticCode': 'TJOvRIv8yCrZuquX',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-31 21:21:20',
#    'updateTime': '2024-08-31 21:21:20',
#    'creator': 'Admin',
#    'updator': 'Admin'},
#   {'id': 208,
#    'authenticCode': 'uD42koblCcm8dmNx',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-31 21:21:20',
#    'updateTime': '2024-08-31 21:56:36',
#    'creator': 'Admin',
#    'updator': 'Admin'},
#   {'id': 209,
#    'authenticCode': 'G9daih8tKg',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-31 21:54:23',
#    'updateTime': '2024-08-31 21:56:36',
#    'creator': 'Admin',
#    'updator': 'Admin'},
#   {'id': 210,
#    'authenticCode': 'lHZ3QhEdTK',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-31 21:54:23',
#    'updateTime': '2024-08-31 21:54:23',
#    'creator': 'Admin',
#    'updator': 'Admin'},
#   {'id': 211,
#    'authenticCode': 'S4iRfqPr8p',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-31 21:54:23',
#    'updateTime': '2024-08-31 21:54:23',
#    'creator': 'Admin',
#    'updator': 'Admin'},
#   {'id': 212,
#    'authenticCode': 'mJb2ISFUZk',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-31 21:54:23',
#    'updateTime': '2024-08-31 21:56:36',
#    'creator': 'Admin',
#    'updator': 'Admin'},
#   {'id': 213,
#    'authenticCode': 'dIyjKrxTXN',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-31 21:54:23',
#    'updateTime': '2024-08-31 21:56:36',
#    'creator': 'Admin',
#    'updator': 'Admin'},
#   {'id': 214,
#    'authenticCode': '4IO4Rc8NtQ',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-31 21:54:23',
#    'updateTime': '2024-08-31 21:54:23',
#    'creator': 'Admin',
#    'updator': 'Admin'},
#   {'id': 215,
#    'authenticCode': 'fsuG8ArPIl',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-31 21:54:23',
#    'updateTime': '2024-08-31 21:54:23',
#    'creator': 'Admin',
#    'updator': 'Admin'},
#   {'id': 216,
#    'authenticCode': 'DrCCIMxgYh',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-31 21:54:23',
#    'updateTime': '2024-08-31 21:56:36',
#    'creator': 'Admin',
#    'updator': 'Admin'},
#   {'id': 217,
#    'authenticCode': '6Ucy1BdDbD',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-31 21:54:23',
#    'updateTime': '2024-08-31 21:56:36',
#    'creator': 'Admin',
#    'updator': 'Admin'},
#   {'id': 218,
#    'authenticCode': 'HqwNN4RJb9',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-31 21:54:23',
#    'updateTime': '2024-08-31 21:54:23',
#    'creator': 'Admin',
#    'updator': 'Admin'},
#   {'id': 219,
#    'authenticCode': 'JZeaMsbxSr',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-31 21:54:23',
#    'updateTime': '2024-08-31 21:54:23',
#    'creator': 'Admin',
#    'updator': 'Admin'},
#   {'id': 220,
#    'authenticCode': 'glm3KAcsJI',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-31 21:54:23',
#    'updateTime': '2024-08-31 21:56:36',
#    'creator': 'Admin',
#    'updator': 'Admin'},
#   {'id': 221,
#    'authenticCode': 'xEJSyq52I5',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-31 21:54:23',
#    'updateTime': '2024-08-31 21:54:23',
#    'creator': 'Admin',
#    'updator': 'Admin'},
#   {'id': 222,
#    'authenticCode': '8WBRx4z07x',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-31 21:54:23',
#    'updateTime': '2024-08-31 21:54:23',
#    'creator': 'Admin',
#    'updator': 'Admin'},
#   {'id': 223,
#    'authenticCode': 'jD76ldcar6',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-31 21:54:23',
#    'updateTime': '2024-08-31 21:54:23',
#    'creator': 'Admin',
#    'updator': 'Admin'},
#   {'id': 224,
#    'authenticCode': 'fVZKSgHm12',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-31 21:54:23',
#    'updateTime': '2024-08-31 21:56:50',
#    'creator': 'Admin',
#    'updator': 'Admin'},
#   {'id': 225,
#    'authenticCode': 'qmaSerenGT',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-31 21:54:23',
#    'updateTime': '2024-08-31 21:54:23',
#    'creator': 'Admin',
#    'updator': 'Admin'},
#   {'id': 226,
#    'authenticCode': 'XwnLnRByFn',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-31 21:54:23',
#    'updateTime': '2024-08-31 21:54:23',
#    'creator': 'Admin',
#    'updator': 'Admin'},
#   {'id': 227,
#    'authenticCode': 'Gv8jWKz7Fp',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-31 21:54:23',
#    'updateTime': '2024-08-31 21:54:23',
#    'creator': 'Admin',
#    'updator': 'Admin'},
#   {'id': 228,
#    'authenticCode': 'SIocpwed71',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-31 21:54:23',
#    'updateTime': '2024-08-31 21:56:36',
#    'creator': 'Admin',
#    'updator': 'Admin'},
#   {'id': 229,
#    'authenticCode': 'GzScYyHN12',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-31 21:54:23',
#    'updateTime': '2024-08-31 21:54:23',
#    'creator': 'Admin',
#    'updator': 'Admin'},
#   {'id': 230,
#    'authenticCode': '3dfPf44dEt',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-31 21:54:23',
#    'updateTime': '2024-08-31 21:54:23',
#    'creator': 'Admin',
#    'updator': 'Admin'},
#   {'id': 231,
#    'authenticCode': 's2xaJaplJv',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-31 21:54:23',
#    'updateTime': '2024-08-31 21:54:23',
#    'creator': 'Admin',
#    'updator': 'Admin'},
#   {'id': 232,
#    'authenticCode': '2dz1ZfxVxW',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-31 21:54:23',
#    'updateTime': '2024-08-31 21:56:36',
#    'creator': 'Admin',
#    'updator': 'Admin'},
#   {'id': 233,
#    'authenticCode': '8fhTIXVm8J',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-31 21:54:23',
#    'updateTime': '2024-08-31 21:54:23',
#    'creator': 'Admin',
#    'updator': 'Admin'},
#   {'id': 234,
#    'authenticCode': '6lRXTvsqrv',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-31 21:54:23',
#    'updateTime': '2024-08-31 21:54:23',
#    'creator': 'Admin',
#    'updator': 'Admin'},
#   {'id': 235,
#    'authenticCode': 'wcGRnW1GM9',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-31 21:54:23',
#    'updateTime': '2024-08-31 21:54:23',
#    'creator': 'Admin',
#    'updator': 'Admin'},
#   {'id': 236,
#    'authenticCode': '8iXyvafwnL',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-31 21:54:23',
#    'updateTime': '2024-08-31 21:56:36',
#    'creator': 'Admin',
#    'updator': 'Admin'},
#   {'id': 237,
#    'authenticCode': 'E1oNwtfZSf',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-31 21:54:23',
#    'updateTime': '2024-08-31 21:54:23',
#    'creator': 'Admin',
#    'updator': 'Admin'},
#   {'id': 238,
#    'authenticCode': 'wx0vuYl034',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-31 21:54:23',
#    'updateTime': '2024-08-31 21:54:23',
#    'creator': 'Admin',
#    'updator': 'Admin'},
#   {'id': 239,
#    'authenticCode': 'FzvwAMqrT7',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-31 21:54:23',
#    'updateTime': '2024-08-31 21:54:23',
#    'creator': 'Admin',
#    'updator': 'Admin'},
#   {'id': 240,
#    'authenticCode': 'L3wCcdWauQ',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-31 21:54:23',
#    'updateTime': '2024-08-31 21:56:36',
#    'creator': 'Admin',
#    'updator': 'Admin'},
#   {'id': 241,
#    'authenticCode': 'SyUPsz6mgI',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-31 21:54:23',
#    'updateTime': '2024-08-31 21:54:23',
#    'creator': 'Admin',
#    'updator': 'Admin'},
#   {'id': 242,
#    'authenticCode': 'USunhKq8oO',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-31 21:54:23',
#    'updateTime': '2024-08-31 21:54:23',
#    'creator': 'Admin',
#    'updator': 'Admin'},
#   {'id': 243,
#    'authenticCode': '9qgECoYmn9',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-31 21:54:23',
#    'updateTime': '2024-08-31 21:54:23',
#    'creator': 'Admin',
#    'updator': 'Admin'},
#   {'id': 244,
#    'authenticCode': 'Ec6BLY3OkF',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-31 21:54:23',
#    'updateTime': '2024-08-31 21:56:36',
#    'creator': 'Admin',
#    'updator': 'Admin'},
#   {'id': 245,
#    'authenticCode': 'KbukJtqJKS',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-31 21:54:23',
#    'updateTime': '2024-08-31 21:54:23',
#    'creator': 'Admin',
#    'updator': 'Admin'},
#   {'id': 246,
#    'authenticCode': 'uIZfU41O1U',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-31 21:54:23',
#    'updateTime': '2024-08-31 21:54:23',
#    'creator': 'Admin',
#    'updator': 'Admin'},
#   {'id': 247,
#    'authenticCode': 'QSP7aS3XTB',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-31 21:54:23',
#    'updateTime': '2024-08-31 21:54:23',
#    'creator': 'Admin',
#    'updator': 'Admin'},
#   {'id': 248,
#    'authenticCode': 'L3AMWAshdR',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-31 21:54:23',
#    'updateTime': '2024-08-31 21:56:36',
#    'creator': 'Admin',
#    'updator': 'Admin'},
#   {'id': 249,
#    'authenticCode': 'syxRnmKOQO',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-31 21:54:23',
#    'updateTime': '2024-08-31 21:54:23',
#    'creator': 'Admin',
#    'updator': 'Admin'},
#   {'id': 250,
#    'authenticCode': 't8ajdGfc1L',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-31 21:54:23',
#    'updateTime': '2024-08-31 21:54:23',
#    'creator': 'Admin',
#    'updator': 'Admin'},
#   {'id': 251,
#    'authenticCode': 'gmRMRf16cx',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-31 21:54:23',
#    'updateTime': '2024-08-31 21:54:23',
#    'creator': 'Admin',
#    'updator': 'Admin'},
#   {'id': 252,
#    'authenticCode': 'DTTbCqNJvy',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-31 21:54:23',
#    'updateTime': '2024-08-31 21:56:36',
#    'creator': 'Admin',
#    'updator': 'Admin'},
#   {'id': 253,
#    'authenticCode': 'ix3ss8O0Cs',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-31 21:54:23',
#    'updateTime': '2024-08-31 21:54:23',
#    'creator': 'Admin',
#    'updator': 'Admin'},
#   {'id': 254,
#    'authenticCode': '7DvcwnqrKn',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-31 21:54:23',
#    'updateTime': '2024-08-31 21:54:23',
#    'creator': 'Admin',
#    'updator': 'Admin'},
#   {'id': 255,
#    'authenticCode': 'tqHKCCukjV',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-31 21:54:23',
#    'updateTime': '2024-08-31 21:54:23',
#    'creator': 'Admin',
#    'updator': 'Admin'},
#   {'id': 256,
#    'authenticCode': '1XcL7PnjxF',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'no',
#    'createTime': '2024-08-31 21:54:23',
#    'updateTime': '2024-08-31 21:56:36',
#    'creator': 'Admin',
#    'updator': 'Admin'},
#   {'id': 257,
#    'authenticCode': 'th89H4AhVi',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-31 21:54:23',
#    'updateTime': '2024-08-31 21:54:23',
#    'creator': 'Admin',
#    'updator': 'Admin'},
#   {'id': 258,
#    'authenticCode': 'VBeaTNcXRp',
#    'productInfo': '',
#    'status': 'nonactivated',
#    'availability': 'yes',
#    'createTime': '2024-08-31 21:54:23',
#    'updateTime': '2024-08-31 21:54:23',
#    'creator': 'Admin',
#    'updator': 'Admin'}]}

# %% [markdown]
# # 修改Availability

# %%
url = 'http://ordermanage.df-ordermanage.com/ordermanage/authenticCode/query/all'
headers = {
    'authorization': token
}
data = {
    'userName': '冬明'
}
res = requests.post(url=url, headers=headers, json=data)
res.json()

# %% [markdown]
# # 查询Indexes

# %%
url = 'http://ordermanage.df-ordermanage.com/ordermanage/authenticCode/indexes/query'
headers = {
    'authorization': token
}
data = {
    'userName': '冬明'
}
res = requests.post(url=url, headers=headers, json=data)
res.json()
# Out:
# {'ret': 0,
#  'msg': 'success',
#  'activatedCount': 7,
#  'nonactivatedCount': 222,
#  'availableCount': 46,
#  'unavailableCount': 183}

# %% [markdown]
# # 查询所有用户

# %%
# url = 'http://localhost:9999/user/query/all'
url = 'https://ordermanage.dollto-china.com/user/query/all'
headers = {
    'authorization': token
}
res = requests.post(url=url, headers=headers)
res.json()
# Out:
# -------------------------------------------------------------------
# gaierror                          Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connection.py in _new_conn(self)
#     158             conn = connection.create_connection(
# --> 159                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     160
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      56
# ---> 57     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      58         af, socktype, proto, canonname, sa = res
#
# ~/anaconda3/lib/python3.7/socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     747     addrlist = []
# --> 748     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     749         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 8] nodename nor servname provided, or not known
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     342         try:
# --> 343             self._validate_conn(conn)
#     344         except (SocketTimeout, BaseSSLError) as e:
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#     838         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 839             conn.connect()
#     840
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connection.py in connect(self)
#     300         # Add certificate verification
# --> 301         conn = self._new_conn()
#     302         hostname = self.host
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connection.py in _new_conn(self)
#     167             raise NewConnectionError(
# --> 168                 self, "Failed to establish a new connection: %s" % e)
#     169
#
# NewConnectionError: <urllib3.connection.VerifiedHTTPSConnection object at 0x7f9c282bf978>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                     Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     637             retries = retries.increment(method, url, error=e, _pool=self,
# --> 638                                         _stacktrace=sys.exc_info()[2])
#     639             retries.sleep()
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     397         if new_retry.is_exhausted():
# --> 398             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     399
#
# MaxRetryError: HTTPSConnectionPool(host='ordermanage.dollto-china.com', port=443): Max retries exceeded with url: /user/query/all (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7f9c282bf978>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                   Traceback (most recent call last)
# <ipython-input-14-d5797660706e> in <module>
#       7     'authenticCode': 'xyz'
#       8 }
# ----> 9 res = requests.post(url=url, headers=headers)
#      10 res.json()
#
# ~/anaconda3/lib/python3.7/site-packages/requests/api.py in post(url, data, json, **kwargs)
#     114     """
#     115
# --> 116     return request('post', url, data=data, json=json, **kwargs)
#     117
#     118
#
# ~/anaconda3/lib/python3.7/site-packages/requests/api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# ~/anaconda3/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~/anaconda3/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~/anaconda3/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     514                 raise SSLError(e, request=request)
#     515
# --> 516             raise ConnectionError(e, request=request)
#     517
#     518         except ClosedPoolError as e:
#
# ConnectionError: HTTPSConnectionPool(host='ordermanage.dollto-china.com', port=443): Max retries exceeded with url: /user/query/all (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7f9c282bf978>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))

# %% [markdown]
# # 查询用户角色

# %%
# url = 'http://localhost:9999/user/query/role'
url = 'https://ordermanage.dollto-china.com/user/query/role'
headers = {
    'authorization': token
}
data = {
    'userName': 'Kevin'
}
res = requests.post(url=url, headers=headers, json=data)
res.json()
# Out:
# {'ret': 0, 'msg': 'success', 'data': [{'role': 'normalUser'}]}

# %% [markdown]
# # 修改用户权限

# %%
# url = 'http://localhost:9999/user/update/permission'
url = 'https://ordermanage.dollto-china.com/user/update/permission'
headers = {
    'authorization': token
}
data = {
    'userName': 'zdm',
    'data': {
        'brandName': 'All',
        'orderPlacedDate': 1
    }
}
res = requests.post(url=url, headers=headers, json=data)
res.json()
# Out:
# {'ret': 0, 'msg': 'success'}

# %% [markdown]
# # 修改注册码

# %%
url = 'http://localhost:9999/signupCode/update'
# url = 'https://ordermanage.dollto-china.com/signupCode/update'
headers = {
    'authorization': token
}
data = {
    'signupCode': 'DF168'
}
res = requests.post(url=url, headers=headers, json=data)
res.json()
# Out:
# {'ret': 0, 'msg': 'success'}

# %% [markdown]
# # 获取注册码

# %%
url = 'http://localhost:9999/signupCode/query'
# url = 'https://ordermanage.dollto-china.com/signupCode/query'
res = requests.post(url=url)
res.json()
# Out:
# {'ret': 0, 'msg': 'success', 'singupCode': 'DF168'}

# %% [markdown]
# # 查询

# %%
# url = 'http://localhost:9999/ordermanage/order/query/date'
url = 'https://ordermanage.dollto-china.com/ordermanage/order/query/date'
headers = {
    'authorization': token
}
data = {
    'userName': '冬明',
    'startDate': '2021-02-15',
    'endDate': '2021-02-15'
}
res = requests.post(url=url, headers=headers, json=data)
res.json()
# Out:
# {'ret': 0, 'msg': 'success', 'data': []}

# %% [markdown]
# # 新增

# %%
url = 'http://localhost:9999/ordermanage/order/add'
# url = 'https://ordermanage.dollto-china.com/ordermanage/order/add'
headers = {
    'authorization': token
}
data = {
        'userName': '冬明',
        'orderPlacedDate': '2022-08-31',
        'orderId': 'DFK-280-DTC210161',
        'comment': '修改下',
        'comment1': '无',
        'comment2': '无',
        'orderSource': 'Kimi',
        'paymentMethod': '支付宝',
        'brandName': 'DFK',
        'height': '155cm',
        'bodyShape': '大胸',
        'head': 'Elisa',
        'paymentUSD': 1500,
        'paymentCNY': 9000,
        'factoryCost': 4000,
        'outfit': 1000,
        'eye': 1000,
        'wig': 1000,
        'implanted': 1000,
        'inserts': 1000,
        'EVO': 1000,
        'extraHead': 1000,
        'luckyBox': 1000,
        'hanger': 1000,
        'standing': 1000,
        'headBoxShippingCost': 130,
        'flightCase': 1000,
        'other': 1000,
        'DHLEUB': 1000,
        "accessoriesPrice":12,
        "otherAccessories":12,
        'shippingCost': 100,
        'totalProfit': 5000,
        'commission': 500,
        'commissionPercentage': 10,
        'designer': 1000,
        'companyProfit': 3500,
        'confirmTime': '2021-01-13',
        'shipTime': '2021-01-18',
        'shippingAgent': '小唐',
        'trackingNumber': '胜利通3435545465656',
        'shippingAddress': '【小唐】 深圳市環世航國際貨運代理有限公司 / 深圳市宝安区福永镇怀德新村咸田2区5巷13号A栋1楼 電話：15920002360 / 連絡人：唐灿煌',
        'salesRep': 'Kevin',
        'checkStatus': '001'
}
res = requests.post(url=url, headers=headers, json=data)
res.json()
# Out:
# {'ret': 0, 'msg': 'success'}

# %% [markdown]
# # 删除

# %%
url = 'http://localhost:9999/ordermanage/order/delete'
data = {
    'id': '23'
}
res = requests.post(url=url, json=data)

# %%
res.json()
# Out:
# {'ret': 0, 'msg': 'success'}

# %% [markdown]
# # 全部修改

# %%
url = 'http://localhost:9999/ordermanage/order/update'
headers = {
    'authorization': token
}
data = {
        'userName': '冬明',
        'id': 1458,
        'monthNumber': 12,
        'yearNumber': 100,
        'orderPlacedDate': '2022-09-01',
        'orderId': 'DFK-280-DTC210169',
        'comment': '修改下',
        'comment1': '无',
        'comment2': '无',
        'orderSource': 'Kimi',
        'paymentMethod': '支付宝',
        'brandName': 'DFK',
        'height': '155cm',
        'bodyShape': '大胸',
        'head': 'Elisa',
        'paymentUSD': 1500,
        'paymentCNY': 9000,
        'factoryCost': 4000,
        'outfit': 1000,
        'eye': 1000,
        'wig': 1000,
        'implanted': 1000,
        'inserts': 1000,
        'EVO': 1000,
        'extraHead': 1000,
        'luckyBox': 1000,
        'hanger': 1000,
        'standing': 1000,
        'headBoxShippingCost': 130,
        'flightCase': 1000,
        'other': 1000,
        'DHLEUB': 1000,
        "accessoriesPrice":12,
        "otherAccessories":12,
        'shippingCost': 100,
        'totalProfit': 5000,
        'commission': 500,
        'commissionPercentage': 10,
        'designer': 1000,
        'companyProfit': 3500,
        'confirmTime': '2021-01-13',
        'shipTime': '2021-01-18',
        'shippingAgent': '小唐',
        'trackingNumber': '胜利通3435545465656',
        'shippingAddress': '【小唐】 深圳市環世航國際貨運代理有限公司 / 深圳市宝安区福永镇怀德新村咸田2区5巷13号A栋1楼 電話：15920002360 / 連絡人：唐灿煌',
        'salesRep': 'Kevin',
        'checkStatus': '001'
}
res = requests.post(url=url, headers=headers, json=data)
res.json()
# Out:
# {'ret': 0, 'msg': 'success'}

# %%
vals = ret

# %%
keys = [list(i)[0] for i in keys]

# %%
ret = {keys[i]:vals[i] for i in range(len(vals))}

# %%
ret['comment'] = '修改下'

# %%
ret
# Out:
# {'id': 18,
#  'orderPlacedDate': datetime.date(2021, 2, 13),
#  'yearNumber': '2021',
#  'monthNumber': '2',
#  'orderId': 'DFK-280-DTC210167',
#  'comment': '修改下',
#  'comment1': '无',
#  'comment2': '无',
#  'orderSource': 'Kimi',
#  'paymentMethod': '支付宝',
#  'brandName': 'DFK',
#  'height': '155cm',
#  'bodyShape': '大胸',
#  'head': 'Elisa',
#  'paymentUSD': 1500,
#  'paymentCNY': 9000,
#  'factoryCost': 4000,
#  'outfit': '加购10号衣服',
#  'eye': '蓝色，加购绿色，紫色，红色',
#  'wig': '#9，加购#11，#19',
#  'implanted': '不需要',
#  'inserts': '#8',
#  'EVO': 'EVO',
#  'extraHead': '不需要',
#  'luckyBox': '不需要',
#  'hanger': '需要',
#  'standing': '非站立',
#  'headBoxShippingCost': 130,
#  'flightCase': '不需要',
#  'other': '无',
#  'DHLEUB': 'DHL',
#  'shippingCost': 100,
#  'totalProfit': 5000,
#  'commission': 500,
#  'designer': 1000,
#  'companyProfit': 3500,
#  'leadTime': datetime.date(2021, 1, 10),
#  'confirmTime': datetime.date(2021, 1, 13),
#  'okToShipTime': datetime.date(2021, 1, 15),
#  'shipTime': datetime.date(2021, 1, 18),
#  'shippingAgent': '小唐',
#  'trackingNumber': '胜利通3435545465656',
#  'shippingAddress': '【小唐】 深圳市環世航國際貨運代理有限公司 / 深圳市宝安区福永镇怀德新村咸田2区5巷13号A栋1楼 電話：15920002360 / 連絡人：唐灿煌',
#  'salesRep': 'Kevin',
#  'checkStatus': None}

# %%
s = 'UPDATE order_tbl SET orderPlacedDate = ?, yearNumber = ?, monthNumber = ?, orderId = ?, comment = ?, comment1 = ?, comment2 = ?, orderSource = ?, paymentMethod = ?, brandName = ?, height = ?, bodyShape = ?, head = ?, paymentUSD = ?, paymentCNY = ?, factoryCost = ?, outfit = ?, eye = ?, wig = ?, implanted = ?, inserts = ?, EVO = ?, extraHead = ?, luckyBox = ?, hanger = ?, standing = ?, headBoxShippingCost = ?, flightCase = ?, other = ?, DHLEUB = ?, shippingCost = ?, totalProfit = ?, commission = ?, designer = ?, companyProfit = ?, leadTime = ?, confirmTime = ?, okToShipTime = ?, shipTime = ?, shippingAgent = ?, trackingNumber = ?, shippingAddress = ?, salesRep = ?, checkStatus = ?'

# %%
s.split('?')
# Out:
# ['UPDATE order_tbl SET orderPlacedDate = ',
#  ', yearNumber = ',
#  ', monthNumber = ',
#  ', orderId = ',
#  ', comment = ',
#  ', comment1 = ',
#  ', comment2 = ',
#  ', orderSource = ',
#  ', paymentMethod = ',
#  ', brandName = ',
#  ', height = ',
#  ', bodyShape = ',
#  ', head = ',
#  ', paymentUSD = ',
#  ', paymentCNY = ',
#  ', factoryCost = ',
#  ', outfit = ',
#  ', eye = ',
#  ', wig = ',
#  ', implanted = ',
#  ', inserts = ',
#  ', EVO = ',
#  ', extraHead = ',
#  ', luckyBox = ',
#  ', hanger = ',
#  ', standing = ',
#  ', headBoxShippingCost = ',
#  ', flightCase = ',
#  ', other = ',
#  ', DHLEUB = ',
#  ', shippingCost = ',
#  ', totalProfit = ',
#  ', commission = ',
#  ', designer = ',
#  ', companyProfit = ',
#  ', leadTime = ',
#  ', confirmTime = ',
#  ', okToShipTime = ',
#  ', shipTime = ',
#  ', shippingAgent = ',
#  ', trackingNumber = ',
#  ', shippingAddress = ',
#  ', salesRep = ',
#  ', checkStatus = ',
#  '']

# %%
191-148+1
# Out:
# 44

# %%
t = 'order.orderPlacedDate,order.yearNumber,order.monthNumber,order.orderId,order.comment,order.comment1,order.comment2,order.orderSource,order.paymentMethod,order.brandName,order.height,order.bodyShape,order.head,order.paymentUSD,order.paymentCNY,order.factoryCost,order.outfit,order.eye,order.wig,order.implanted,order.inserts,order.EVO,order.extraHead,order.luckyBox,order.hanger,order.standing,order.headBoxShippingCost,order.flightCase,order.other,order.DHLEUB,order.shippingCost,order.totalProfit,order.commission,order.designer,order.companyProfit,order.leadTime,order.confirmTime,order.okToShipTime,order.shipTime,order.shippingAgent,order.trackingNumber,order.shippingAddress,order.salesRep,order.checkStatus'

# %%
t.split(',')
# Out:
# ['order.orderPlacedDate',
#  'order.yearNumber',
#  'order.monthNumber',
#  'order.orderId',
#  'order.comment',
#  'order.comment1',
#  'order.comment2',
#  'order.orderSource',
#  'order.paymentMethod',
#  'order.brandName',
#  'order.height',
#  'order.bodyShape',
#  'order.head',
#  'order.paymentUSD',
#  'order.paymentCNY',
#  'order.factoryCost',
#  'order.outfit',
#  'order.eye',
#  'order.wig',
#  'order.implanted',
#  'order.inserts',
#  'order.EVO',
#  'order.extraHead',
#  'order.luckyBox',
#  'order.hanger',
#  'order.standing',
#  'order.headBoxShippingCost',
#  'order.flightCase',
#  'order.other',
#  'order.DHLEUB',
#  'order.shippingCost',
#  'order.totalProfit',
#  'order.commission',
#  'order.designer',
#  'order.companyProfit',
#  'order.leadTime',
#  'order.confirmTime',
#  'order.okToShipTime',
#  'order.shipTime',
#  'order.shippingAgent',
#  'order.trackingNumber',
#  'order.shippingAddress',
#  'order.salesRep',
#  'order.checkStatus']

# %% [markdown]
# # 修改checkStatus

# %%
url = 'http://localhost:9999/ordermanage/order/update/checkStatus'
url = 'https://ordermanage.dollto-china.com/ordermanage/order/update/checkStatus'
headers = {
    'authorization': token
}
data = {
    'userName': '冬明',
    'id': '431',
    'checkStatus': '0101'
}
res = requests.post(url=url, headers=headers, json=data)
res.json()
# Out:
# {'ret': 0, 'msg': 'success'}

# %% [markdown]
# # 修改orderFlag

# %%
url = 'http://localhost:9999/ordermanage/order/update/orderFlag'
url = 'https://ordermanage.dollto-china.com/ordermanage/order/update/orderFlag'
headers = {
    'authorization': token
}
data = {
    'userName': '冬明',
    'id': '431',
    'orderFlag': 'Yes'
}
res = requests.post(url=url, headers=headers, json=data)
res.json()
# Out:
# {'ret': 0, 'msg': 'success'}

# %% [markdown]
# # 增加shippingAgent

# %%
# url = 'http://localhost:9999/ordermanage/shippingAgent/add'
url = 'https://ordermanage.dollto-china.com/ordermanage/shippingAgent/add'
headers = {
    'authorization': token
}
data = {
    'userName': '冬明',
    'shippingAgent': '中国邮政'
}
res = requests.post(url=url, headers=headers, json=data)
try:
    print(res.json())
except:
    print(res.text)
# Out:
# {'ret': 0, 'msg': 'success'}

# %% [markdown]
# # 删除shippingAgent

# %%
url = 'http://localhost:9999/ordermanage/shippingAgent/delete'
# url = 'https://ordermanage.dollto-china.com/ordermanage/shippingAgent/delete'
headers = {
    'authorization': token
}
data = {
    'userName': '冬明',
    'shippingAgent': '大唐'
}
res = requests.post(url=url, headers=headers, json=data)
try:
    res.json()
    token = res.json()['token']
except:
    print(res.text)
# Out:
# {"ret":0,"msg":"success"}

# %% [markdown]
# # 修改shippingAgent

# %%
url = 'http://localhost:9999/ordermanage/shippingAgent/update'
# url = 'https://ordermanage.dollto-china.com/ordermanage/shippingAgent/update'
headers = {
    'authorization': token
}
data = {
    'userName': '冬明',
    'oldShippingAgent': '小小唐',
    'newShippingAgent': '大唐'
}
res = requests.post(url=url, headers=headers, json=data)
try:
    res.json()
    token = res.json()['token']
except:
    print(res.text)
# Out:
# {"ret":0,"msg":"success"}

# %% [markdown]
# # 查询shippingAgent

# %%
# url = 'http://localhost:9999/ordermanage/shippingAgent/query'
url = 'https://ordermanage.dollto-china.com/ordermanage/shippingAgent/query'
headers = {
    'authorization': token
}
data = {
    'userName': '冬明'
}
res = requests.post(url=url, headers=headers, json=data)
try:
    print(res.json())
except:
    print(res.text)
# Out:
# {'ret': 0, 'msg': 'success', 'data': [{'shippingAgent': 'EUB'}, {'shippingAgent': '中国邮政'}, {'shippingAgent': '大唐'}, {'shippingAgent': '宁波本地'}, {'shippingAgent': '小唐'}, {'shippingAgent': '林立军'}]}

# %% [markdown]
# # 增加brandName

# %%
# url = 'http://localhost:9999/ordermanage/brandName/add'
url = 'https://ordermanage.dollto-china.com/ordermanage/brandName/add'
headers = {
    'authorization': token
}
data = {
    'userName': '冬明',
    'brandName': 'DFK'
}
res = requests.post(url=url, headers=headers, json=data)
try:
    print(res.json())
except:
    print(res.text)
# Out:
# {'ret': 0, 'msg': 'success'}

# %% [markdown]
# # 删除brandName

# %%
# url = 'http://localhost:9999/ordermanage/brandName/delete'
url = 'https://ordermanage.dollto-china.com/ordermanage/brandName/delete'
headers = {
    'authorization': token
}
data = {
    'userName': '冬明',
    'brandName': '70KOS'
}
res = requests.post(url=url, headers=headers, json=data)
try:
    print(res.json())
except:
    print(res.text)
# Out:
# {'ret': 0, 'msg': 'success'}

# %% [markdown]
# # 修改brandName

# %%
url = 'http://localhost:9999/ordermanage/brandName/update'
# url = 'https://ordermanage.dollto-china.com/ordermanage/brandName/update'
headers = {
    'authorization': token
}
data = {
    'userName': '冬明',
    'oldbrandName': '70KOS',
    'newbrandName': '60KOS'
}
res = requests.post(url=url, headers=headers, json=data)
try:
    print(res.json())
except:
    print(res.text)
# Out:
# {'ret': 0, 'msg': 'success'}

# %% [markdown]
# # 查询brandName

# %%
url = 'http://localhost:9999/ordermanage/brandName/query'
# url = 'https://ordermanage.dollto-china.com/ordermanage/brandName/query'
headers = {
    'authorization': token
}
data = {
    'userName': '冬明'
}
res = requests.post(url=url, headers=headers, json=data)
try:
    print(res.json())
except:
    print(res.text)
# Out:
# {'ret': 0, 'msg': 'success', 'data': []}

# %% [markdown]
# # 根据orderId查询订单

# %%
url = 'http://localhost:9999/ordermanage/order/query/orderId'
# url = 'https://ordermanage.dollto-china.com/ordermanage/order/query/orderId'
headers = {
    'authorization': token
}
data = {
    'userName': '冬明',
    'orderId': 'DTC22'
}
res = requests.post(url=url, headers=headers, json=data)
try:
    print(res.json())
except:
    print(res.text)
# Out:
# {'ret': 0, 'msg': 'success', 'data': []}

# %% [markdown]
# # 查询numbers

# %%
url = 'http://localhost:9999/ordermanage/order/query/numbers'
# url = 'https://ordermanage.dollto-china.com/ordermanage/order/query/numbers'
headers = {
    'authorization': token
}
data = {
    'userName': '冬明',
    'orderPlacedDate': '2021-02-15'
}
res = requests.post(url=url, headers=headers, json=data)
res.json()
# Out:
# {'ret': 0, 'msg': 'success', 'yearNumber': 9, 'monthNumber': 4}
